# %% [markdown]
# # Setup and Import

# %%
import re
import fitz  # PyMuPDF
import base64
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
client = OpenAI()
with open('../docs/prompts.md', 'r') as prompts_file:
    prompts_content = prompts_file.read()
pdf_path = "test_paper/black_spatula.pdf"

# %% [markdown]
# ## Extraction functions

# %%
def extract_images_from_pdf(pdf_path:str) -> list:
    """
    Extracts images from a PDF, converts them to base64-encoded strings, 
    and prepares messages with base64-encoded images.

    Args:
        pdf_path (str): Path to the PDF file.

    Returns:
        list: A list of message dictionaries containing base64-encoded images.
    """
    pdf_document = fitz.open(pdf_path)
    messages = [{"role": "user", "content": []}]

    for page_num in range(len(pdf_document)):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()
        image_bytes = pix.tobytes("png")
        image_base64 = base64.b64encode(image_bytes).decode('utf-8')
        image_data_url = f"data:image/png;base64,{image_base64}"
        messages[0]["content"].append({
            "type": "image_url", 
            "image_url": {"url": image_data_url}
        })

    return messages

def extract_text_from_pdf(pdf_path:str) -> str:
    """
    Extracts all text content from a PDF file.

    Args:
        pdf_path (str): Path to the PDF file.

    Returns:
        str: A single string containing the concatenated text from all PDF pages.
    """
    pdf_document = fitz.open(pdf_path)
    extracted_text = []

    for page_num in range(len(pdf_document)):
        page = pdf_document.load_page(page_num)
        text = page.get_text()
        extracted_text.append(text)
    full_text = "\n".join(extracted_text)
    messages = [{"role": "user", "content": [{"type": "text", "text": full_text}]}]
    return messages

def extract_prompt_content(markdown_text:str, prompt_number:int) -> str:
    """
    Extracts the content of a specific prompt's code block from the given Markdown text.
    
    Args:
        markdown_text (str): The full text containing prompts in Markdown format.
        prompt_number (int): The prompt number (e.g., 1, 2, 3) to extract content for.

    Returns:
        str: The extracted content inside the code block below the specified prompt.
    """
    pattern = rf"### Prompt {prompt_number}\s*```.*?\n(.*?)```"
    match = re.search(pattern, markdown_text, re.DOTALL)
    if match:
        return match.group(1).strip()
    else:
        return f"Prompt {prompt_number} not found or has no associated code block."
    
def extract_page_content(pdf_path:str, page_number:int) -> dict:
    """
    Extracts raw text and a base64-encoded image from a specified page of a PDF.

    Args:
        pdf_path (str): Path to the PDF file.
        page_number (int): The page number to extract content from (0-based index).

    Returns:
        dict: A dictionary containing raw text and base64-encoded image data for the specified page.
    """
    pdf_document = fitz.open(pdf_path)
    if page_number < 0 or page_number >= len(pdf_document):
        raise ValueError("Page number out of range.")
    page = pdf_document.load_page(page_number)
    raw_text = page.get_text()
    pix = page.get_pixmap()
    image_bytes = pix.tobytes("png")
    image_base64 = base64.b64encode(image_bytes).decode('utf-8')
    image_data_url = f"data:image/png;base64,{image_base64}"
    result = {
        "page_number": page_number,
        "raw_text": raw_text,
        "image": {
            "type": "image_url",
            "image_url": {"url": image_data_url}
        }
    }
    return result

def make_extract_page_info_message(pdf_path:str, page_number:int) -> list:
    """
    Extracts all text content and images from a PDF file.

    Args:
        pdf_path (str): Path to the PDF file.
        page_number (int): The page number to extract content from (0-based index).

    Returns:
        list: A list of message dictionaries containing text and image data.
    """
    result = extract_page_content(pdf_path, page_number)
    with open('../docs/prompts.md', 'r') as prompts_file:
        prompts_content = prompts_file.read()
    prompt2_content = extract_prompt_content(prompts_content, 2).format(raw_text=result["raw_text"])
    extract_page_info_messages = [{"role": "user", "content": [{"type": "text", "text": prompt2_content}, result["image"]]}]
    return extract_page_info_messages

# %% [markdown]
# # Tests with prompt1 (images or straight up raw text)

# %%
prompt1_content = extract_prompt_content(prompts_content, 1)

image_messages = extract_images_from_pdf(pdf_path)
image_messages[0]["content"].append({"type": "text", "text": prompt1_content})
text_messages = extract_text_from_pdf(pdf_path)
text_messages[0]["content"].append({"type": "text", "text": prompt1_content})

# %%
completion = client.chat.completions.create(
  model="o1-preview",
  messages=text_messages
)

print(completion.choices[0].message.content)
# Out:
# **Review and Verification of Numerical Calculations in the Article**
#
# After a careful review of the research article, I focused on verifying all arithmetic calculations, unit conversions, numerical comparisons, and quantitative interpretations presented. Below, I detail my findings, including any errors identified and the steps taken to verify the calculations.
#
# ---
#
# ### **1. Calculation of the U.S. EPA Reference Dose (RfD) for BDE-209 and Its Application**
#
# **Location in Article:**
# - **Section:** Health and exposure concerns (Subsection of Results and Discussion)
# - **Paragraph:** "Estimation of exposure to BDE-209 from contaminated kitchen utensils indicated users would have a median intake of 34,700 ng/day, exceeding estimates for intake from dust and diet. The detection of FRs in collected household products indicates that recycling, without the necessary transparency and restrictions to ensure safety, is resulting in unexpected exposure to toxic flame retardants in household items."
# - **Specific Statement:** "... and would approach the U.S. BDE-209 reference dose of 7000 ng/kg bw/day (42,000 ng/day for a 60 kg adult)."
#
# **1.1 What the Calculation Represents:**
# The authors aim to compare the estimated daily intake of BDE-209 from contaminated kitchen utensils to the U.S. EPA's Reference Dose (RfD) for BDE-209. The RfD is an estimate of a daily exposure level for humans that is likely to be without an appreciable risk of deleterious effects during a lifetime.
#
# **1.2 Authors' Arithmetic and Reasoning:**
# - The U.S. EPA RfD for BDE-209 is stated as **7000 ng/kg body weight/day**.
# - To find the total acceptable daily intake for a **60 kg adult**, the authors multiply the RfD by the body weight:
#   \[
#   \text{Acceptable Daily Intake} = 7000 \, \text{ng/kg bw/day} \times 60 \, \text{kg} = 42,000 \, \text{ng/day}
#   \]
#
# **1.3 Errors and Correct Calculation:**
# **Error Identified:** The multiplication appears to be incorrect. Multiplying 7000 ng/kg bw/day by 60 kg should yield 420,000 ng/day, not 42,000 ng/day.
#
# **Correct Calculation:**
# \[
# 7000 \, \text{ng/kg bw/day} \times 60 \, \text{kg} = 420,000 \, \text{ng/day}
# \]
# - Therefore, the correct acceptable daily intake for a 60 kg adult is **420,000 ng/day**.
#
# **1.4 Implications and Reasonableness:**
# - **Implications of Error:** The incorrect calculation underestimates the acceptable daily intake by a factor of **10**.
# - **Impact on Interpretation:** As a result, the authors' statement that the estimated daily intake of **34,700 ng/day** from contaminated utensils "would approach the U.S. BDE-209 reference dose" is incorrect.
# - **Reevaluation of the Claim:**
#   - The estimated intake of 34,700 ng/day is **approximately 8.26%** of the correct RfD (420,000 ng/day):
#     \[
#     \left( \frac{34,700 \, \text{ng/day}}{420,000 \, \text{ng/day}} \right) \times 100\% \approx 8.26\%
#     \]
#   - This intake does **not approach** the RfD, and is well below the acceptable limit set by the U.S. EPA.
# - **Reasonableness:** Given the corrected calculation, the numeric results and interpretations need to be revised to accurately reflect the relationship between the estimated intake and the RfD.
#
# ---
#
# ### **2. Estimation of Daily Intake of BDE-209 from Contaminated Utensils**
#
# **Location in Article:**
# - **Section:** Health and exposure concerns (Subsection of Results and Discussion)
# - **Specific Statement:** "Applying the transfer rate derived in those experiments (11.7%) to the median concentration of BDE-209 in the cooking utensils in this study, we obtained an estimated daily intake of 34,700 ng/day from the use of contaminated utensils (see SI for methods)."
#
# **2.1 What the Calculation Represents:**
# The calculation estimates the daily intake of BDE-209 by consumers using contaminated kitchen utensils, based on:
# - Median concentration of BDE-209 in the utensils.
# - The transfer rate of BDE-209 from utensils to food (11.7%).
# - Assumptions about daily exposure scenarios.
#
# **2.2 Authors' Arithmetic and Reasoning:**
# - **Median Concentration of BDE-209 in Utensils:** 103 mg/kg (from Table 3).
# - **Conversion to ng/g:**
#   \[
#   103 \, \text{mg/kg} = 103 \, \text{mg}/1000 \, \text{g} = 0.103 \, \text{mg/g} = 103,000 \, \text{ng/g}
#   \]
# - **Amount Transferred to Food:**
#   \[
#   103,000 \, \text{ng/g} \times 11.7\% = 12,051 \, \text{ng/g}
#   \]
# - **Estimated Daily Intake:** The authors reference the methods in the Supplementary Information (SI), which are not provided here. However, they conclude an estimated intake of **34,700 ng/day**.
#
# **2.3 Verification and Recalculation:**
# Without access to the SI, we can attempt to reconstruct the calculation.
#
# - **Step 1:** Determine the amount of BDE-209 transferred to food per utensil use.
# - **Step 2:** Estimate the daily exposure based on typical utensil usage patterns.
# - **Assumptions:** Let's assume an average consumer uses utensils that contact a certain mass of food per day.
#
# Given that the authors arrived at **34,700 ng/day**, and the numbers appear consistent with their input values and assumptions, the calculation seems reasonable.
#
# **2.4 Reasonableness in Context:**
# - **Comparison to Other Exposure Sources:**
#   - Home dust ingestion: **~250 ng/day**
#   - Food intake: **~50 ng/day**
#   - **Estimated intake from utensils is significantly higher** than these sources, indicating that contaminated utensils could be a notable exposure pathway.
# - **Relation to Corrected RfD:** With the corrected RfD of **420,000 ng/day**, the estimated intake of **34,700 ng/day** is well below the acceptable daily intake.
#
# ---
#
# ### **3. Conversion of BDE-209 Levels for EU Regulations**
#
# **Location in Article:**
# - **Section:** Results and Discussion
# - **Specific Statement:** "In all 14 of the products containing BDE-209, levels would exceed the 10 mg/kg unintentional trace contamination limit established for the E.U."
#
# **3.1 What the Calculation Represents:**
# The authors are comparing the levels of BDE-209 found in their samples to the European Union's limit for unintentional trace contamination in recycled plastics, which is **10 mg/kg**.
#
# **3.2 Verification:**
# - **Detection Frequency of BDE-209:** 70% (14 out of 20 samples).
# - **Range of BDE-209 Levels:** \<2 – 11,900 mg/kg.
# - **Minimum Reporting Limit:** The detection limit is \<2 mg/kg, and the minimum detected level (excluding non-detects) must be above this.
# - **Authors' Claim:** All 14 products with detected BDE-209 exceed 10 mg/kg.
#
# **3.3 Verification of Claim:**
# - **Consistency Check:** Since the minimum detected level is reported as \<2 mg/kg, and 14 products with BDE-209 were detected, it's reasonable to infer that all detections were above 2 mg/kg.
# - **Given that the EU limit is 10 mg/kg**, it's plausible that all 14 products exceed this limit.
# - **However**, without specific concentrations for each of the 14 products, we cannot definitively confirm this claim.
#
# **3.4 Conclusion:**
# - The authors' claim seems reasonable based on the reported median concentration (103 mg/kg) and detection frequency.
# - **No arithmetic errors are identified** in this claim.
#
# ---
#
# ### **4. Correlation between XRF Br Levels and Total Br Content in BFRs**
#
# **Location in Article:**
# - **Section:** Results and Discussion (Figure 2)
# - **Specific Statement:** "Linear regression assessing the relationship between XRF Br content and the sum of Br content in BFRs detected found a strong and significant association between the two variables (p < 0.01, R² = 0.91)"
#
# **4.1 What the Calculation Represents:**
# The authors conducted a linear regression to assess the correlation between bromine levels measured using X-ray fluorescence (XRF) and the total bromine content calculated from the detected BFRs in the samples.
#
# **4.2 Verification:**
# - **Statistical Analysis:** Linear regression with R² = 0.91 indicates a strong positive correlation.
# - **Significance Level:** p < 0.01 suggests the correlation is statistically significant.
# - **Consistency:** A high R² value is plausible given the expected relationship between XRF Br measurements and actual Br content from BFRs.
#
# **4.3 Conclusion:**
# - **No arithmetic errors are identified** in this analysis.
# - The statistical results are reasonable and consistent with the data presented.
#
# ---
#
# ### **5. Comparison of FR Levels in Different Polymer Types**
#
# **Location in Article:**
# - **Section:** Variation in FR detection by polymer type
# - **Specific Statement:** "Total FR levels in ABS and HIPS/PS, with a median of 4600 mg/kg, were significantly higher than those in polypropylene and polyamide/nylon, with a median of 150 mg/kg (p < 0.01)."
#
# **5.1 What the Calculation Represents:**
# The authors compared the total flame retardant (FR) levels in polymers typically used in electronics (ABS and HIPS/PS) to those not typically used in electronics (polypropylene and nylon). They performed statistical analysis to determine if the difference in FR levels was significant.
#
# **5.2 Verification:**
# - **Median FR Levels:**
#   - ABS and HIPS/PS: 4600 mg/kg
#   - Polypropylene and Nylon: 150 mg/kg
# - **Statistical Significance:** p < 0.01 suggests a statistically significant difference.
#
# **5.3 Conclusion:**
# - **No arithmetic errors are identified**.
# - The statistical conclusion is plausible based on the data.
#
# ---
#
# ### **6. Association Between FR Levels and Retailer Type**
#
# **Location in Article:**
# - **Section:** Association between FR levels and retailer type
# - **Specific Statement:** "The median FR concentration in products purchased from large retailers was higher than that from small retailers (6150 vs. 885 mg/kg), although the difference was not significant (p = 0.07)."
#
# **6.1 What the Calculation Represents:**
# The authors compared the median FR concentrations in products from large retailers to those from small retailers and assessed whether the difference was statistically significant.
#
# **6.2 Verification:**
# - **Median FR Levels:**
#   - Large Retailers: 6150 mg/kg
#   - Small Retailers: 885 mg/kg
# - **Statistical Significance:** p = 0.07 indicates that the difference is not statistically significant at the conventional 0.05 level.
#
# **6.3 Conclusion:**
# - **No arithmetic errors are identified**.
# - The statistical results are reasonable given the p-value.
#
# ---
#
# ### **7. Calculations and Unit Conversions in Tables**
#
# **Tables Reviewed:**
# - **Table 3:** Summary of FRs detected, including detection frequency, median, mean, and range in mg/kg.
#
# **7.1 Verification:**
# - **Conversion Factors:**
#   - 1 mg/kg = 1 part per million (ppm)
#   - 1 mg/kg = 1000 ng/g (since 1 mg = 10^6 ng, 1 kg = 10^6 g)
#
# - **Consistency Check:** The units are consistent throughout the tables and text.
# - **Values in Tables:** Mean and median values align with the ranges provided, and detection frequencies correspond with the number of samples analyzed.
#
# **7.2 Conclusion:**
# - **No arithmetic or unit conversion errors are identified** in the tables.
#
# ---
#
# ### **Overall Assessment**
#
# Except for the significant arithmetic error identified in the calculation of the acceptable daily intake (RfD) for BDE-209, the numerical calculations, unit conversions, and quantitative interpretations in the article appear to be accurate and reasonable within the context of the data and known standards.
#
# ---
#
# **Recommendation for Correction:**
# - The authors should correct the calculation of the acceptable daily intake for BDE-209 to reflect the correct value of **420,000 ng/day** for a 60 kg adult.
# - They should revise their interpretation accordingly, noting that the estimated intake from contaminated utensils is approximately **8%** of the RfD, rather than approaching it.
# - This correction does not diminish the significance of their findings regarding potential exposure from contaminated household items but ensures accuracy in the presentation and interpretation of the data.

# %% [markdown]
# # Test with prompt 2

# %%
extract_page_info_messages = make_extract_page_info_message(pdf_path, 7)

# %%
completion = client.chat.completions.create(
  model="gpt-4o",
  messages=extract_page_info_messages
)

print(completion.choices[0].message.content)
# Out:
# The image displays a page from a document titled "Chemosphere 365 (2024) 143319." It includes text discussing the regulation and concerns about the use of organohalogen flame retardants (FRs) in electronic devices in the EU, New York, and Washington. The text highlights the high levels of FRs found in household products, emphasizing the need for regulatory systems to ensure safer materials. The conclusion section states the importance of eliminating toxic additives in recycled plastic products and mentions the role of authors in producing the document. Acknowledgments and references follow, along with a note on data availability and a link to supplementary data.
